# %% [markdown]
# For this analysis we will look at respective household income extremes in republican vs democratic districts. To do so, we will leverage two data sources that we will need to combine together.
#
# First, we will use the American Community Survey 2021 dataset available from census.gov. The data is available via API from here: https://www.census.gov/data/developers/data-sets/acs-1year.html. This data is commonly referenced when people are looking for demographic breakdowns of the American population. This data refers back to the 116th congressional district.
#
# Second, to get the party affiliation of each congressional district, we will use https://www.house.gov/representatives. Someone has already scraped the house.gov site to turn it into a csv here: http://goodcsv.com/politics/us-house-of-representatives-2020/ for the 116th congressional district.

# %%
# first some initial setup of libraries we will be using
import pandas as pd # this is the main library used in python for manipulating data.
import json # this is a library to parse json (javascript object notation)
from urllib.request import urlopen # library to read data from a URL
import matplotlib.pyplot as plt # visualization library we will use that integrates with pandas

# %% [markdown]
# First we will read the ACS 2021 dataset and get it into a usable state for our data analysis.

# %%
# We are reading in the data we want from ACS 2021. The API returns json data. Try copy and pasting the link yourself in a browser to see what the raw data looks like.
url="https://api.census.gov/data/2021/acs/acs1?get=NAME,B19001_001E,B19001_002E,B19001_017E&for=congressional%20district:*&in=state:*"

# store the response of URL
response = urlopen(url)

# storing the JSON response from url in data
data_json = json.loads(response.read())
data_json.pop(0) # the first row of data is header information which we don't need, so pop removes that from the dataset.

# Hand populate the columns based on the variable descriptions census.gov documents here:
# https://api.census.gov/data/2021/acs/acs1/variables.html. Note they correspond back to the variable names I included in the URL above.
cols = ['District Name','Total Households','Less than $10k', '$200k+', 'State code', 'district number']

acs_df = pd.DataFrame(data_json, columns = cols)

# time to do some basic cleanup of the data. We will need to extract the district number and state in a regular format so we can later join with the party data.
acs_df[['District', 'State']] = acs_df['District Name'].str.split(',', expand=True)
acs_df['district number'] = pd.to_numeric(acs_df['district number'])

acs_df['State'] = acs_df['State'].str.strip()

# Let's just keep the columns we need
acs_df = acs_df[['Total Households', 'Less than $10k', "$200k+", 'district number', 'State']]

# take a look at the top results in the dataset
acs_df.head()
# Out:
#   Total Households Less than $10k $200k+  district number        State
# 0           289474          14153  19390               10     Michigan
# 1           299804          23793  10899                4  Mississippi
# 2           278057          27728  19574               14     Michigan
# 3           306685          19036  12208                1     Michigan
# 4           285554          26481  12412                3  Mississippi

# %%
# Convert the number columns into number data types so we can math on them
acs_df["Total Households"] = pd.to_numeric(acs_df["Total Households"])
acs_df["Less than $10k"] = pd.to_numeric(acs_df["Less than $10k"])
acs_df['$200k+'] = pd.to_numeric(acs_df['$200k+'])

# Compute some new columns based on the existing columns for later visualization
acs_df['% of households over $200k'] = (100*acs_df['$200k+'])/acs_df['Total Households']
acs_df['% of households less than $10k'] = (100*acs_df['Less than $10k'])/acs_df['Total Households']

# now let's look at the data again
acs_df.head()
# Out:
#    Total Households  Less than $10k  $200k+  district number        State  \
# 0            289474           14153   19390               10     Michigan
# 1            299804           23793   10899                4  Mississippi
# 2            278057           27728   19574               14     Michigan
# 3            306685           19036   12208                1     Michigan
# 4            285554           26481   12412                3  Mississippi
#
#    % of households over $200k  % of households less than $10k
# 0                    6.698356                        4.889213
# 1                    3.635375                        7.936185
# 2                    7.039564                        9.972056
# 3                    3.980632                        6.207020
# 4                    4.346638                        9.273552

# %% [markdown]
# Now let's get our party affiliation data in a state to merge with the ACS data.

# %%
# read from the congressional data and put into a pandas dataframe
party_df = pd.read_csv("http://goodcsv.com/wp-content/uploads/2020/08/us-house-of-representatives-2020.csv", encoding = "ISO-8859-1")

# extract the district number from the data (it was in the format of 5th and we want that to just be 5) using a regular expression.
party_df['district number'] = party_df['District/Position'].str.extract('(\d+)')
party_df['district number'] = party_df['district number'].fillna(0)
party_df['district number'] = pd.to_numeric(party_df['district number'])
party_df['State'] = party_df['State/Territory']
party_df['State'] = party_df['State'].str.strip()
party_df['Party'] = party_df['Party'].str.strip() # remove extraneous whitespace

# Let's just keep the columns we need
party_df = party_df[['State', 'Party', "district number"]]

party_df.head(5)
# Out:
#             State Party  district number
# 0       Louisiana     R                5
# 1  North Carolina     D               12
# 2         Alabama     R                4
# 3      California     D               31
# 4         Georgia     R               12

# %% [markdown]
# Let's pull some statistics on the two datasets quickly before we join them so we can sanity check that the join worked ok.

# %%
party_df['State'].value_counts()
# Out:
# California                  53
# Texas                       36
# New York                    27
# Florida                     27
# Pennsylvania                18
# Illinois                    18
# Ohio                        16
# Michigan                    14
# Georgia                     14
# North Carolina              13
# New Jersey                  12
# Virginia                    11
# Washington                  10
# Indiana                      9
# Arizona                      9
# Tennessee                    9
# Massachusetts                9
# Minnesota                    8
# Missouri                     8
# Maryland                     8
# Wisconsin                    8
# Colorado                     7
# Alabama                      7
# South Carolina               7
# Louisiana                    6
# Kentucky                     6
# Oklahoma                     5
# Oregon                       5
# Connecticut                  5
# Nevada                       4
# Kansas                       4
# Arkansas                     4
# Iowa                         4
# Mississippi                  4
# Utah                         4
# West Virginia                3
# Nebraska                     3
# New Mexico                   3
# New Hampshire                2
# Maine                        2
# Rhode Island                 2
# Idaho                        2
# Hawaii                       2
# Montana                      1
# Puerto Rico                  1
# Wyoming                      1
# South Dakota                 1
# Delaware                     1
# North Dakota                 1
# District of Columbia         1
# Virgin Islands               1
# American Samoa               1
# Northern Mariana Islands     1
# Guam                         1
# Vermont                      1
# Alaska                       1
# Name: State, dtype: int64

# %%
acs_df['State'].value_counts()
# Out:
# California              53
# Texas                   36
# Florida                 27
# New York                27
# Illinois                18
# Pennsylvania            18
# Ohio                    16
# Georgia                 14
# Michigan                14
# North Carolina          13
# New Jersey              12
# Virginia                11
# Washington              10
# Indiana                  9
# Massachusetts            9
# Arizona                  9
# Tennessee                9
# Missouri                 8
# Wisconsin                8
# Minnesota                8
# Maryland                 8
# South Carolina           7
# Alabama                  7
# Colorado                 7
# Kentucky                 6
# Louisiana                6
# Connecticut              5
# Oklahoma                 5
# Oregon                   5
# Iowa                     4
# Kansas                   4
# Arkansas                 4
# Mississippi              4
# Nevada                   4
# Utah                     4
# New Mexico               3
# West Virginia            3
# Nebraska                 3
# Rhode Island             2
# New Hampshire            2
# Hawaii                   2
# Idaho                    2
# Maine                    2
# South Dakota             1
# Wyoming                  1
# Alaska                   1
# Montana                  1
# North Dakota             1
# Vermont                  1
# Delaware                 1
# Puerto Rico              1
# District of Columbia     1
# Name: State, dtype: int64

# %% [markdown]
# So the ACS dataset has stats for DC and Puerto Rico. The party datset has other terratories like the Virgin Islands. The state counts look right though. Let's go ahead and merge.

# %%
# Merge is like a sql natural join. We are joining on the State and District numbers being the same between the two sets.
merged_df = pd.merge(acs_df, party_df, on=["State", "district number"])

# %%
merged_df[merged_df["State"] == "Delaware"]
# Out:
#      Total Households  Less than $10k  $200k+  district number     State  \
# 105            395656           20504   33025                0  Delaware
#
#      % of households over $200k  % of households less than $10k Party
# 105                    8.346897                         5.18228     D

# %%
merged_df.describe()
# Out:
#        Total Households  Less than $10k         $200k+  district number  \
# count        435.000000      435.000000     435.000000       435.000000
# mean      292471.643678    17605.977011   28522.944828        10.158621
# std        33670.787672     6047.931263   18902.411362        10.656779
# min       183319.000000     6021.000000    5296.000000         0.000000
# 25%       273747.000000    13416.000000   14916.000000         3.000000
# 50%       292311.000000    16617.000000   22543.000000         6.000000
# 75%       311849.500000    21013.500000   37009.500000        13.000000
# max       448949.000000    44929.000000  111988.000000        53.000000
#
#        % of households over $200k  % of households less than $10k
# count                  435.000000                      435.000000
# mean                     9.721602                        6.050237
# std                      6.417955                        2.106075
# min                      2.025905                        2.208934
# 25%                      5.184740                        4.653305
# 50%                      7.618205                        5.679285
# 75%                     12.689262                        7.036059
# max                     41.846370                       16.858153

# %% [markdown]
# There are 435 total rows, which matches up with the number of congress members in the 116th congress. Looks pretty good. Let's do a final check by looking at party counts.

# %%
# let's take a look at the party breakdown and sanity check that it looks right
merged_df['Party'].value_counts()
# Out:
# D    233
# R    201
# L      1
# Name: Party, dtype: int64

# %% [markdown]
# Let's do our visualization now. We will do a scatter plot of congressional districts and look at the % of households earning over \$200k on one axis and % of households less than $10k on the other axis. We will color the plot based upon the party affiliation of the districts congress member as of the 116th congress.

# %%
R = merged_df[merged_df['Party'].str.contains('R')]
D = merged_df[merged_df['Party'].str.contains('D')]
L = merged_df[merged_df['Party'].str.contains('L')]

fig, ax = plt.subplots(figsize=(15, 12))
R.plot.scatter(x='% of households over $200k', y='% of households less than $10k', c='red',label='Republican', ax=ax)
D.plot.scatter(x='% of households over $200k', y='% of households less than $10k',c='blue',label='Democrat', ax=ax)
L.plot.scatter(x='% of households over $200k', y='% of households less than $10k',c='gold',label='Libertarian', ax=ax)

#for i, txt in enumerate(df['State']):
#   ax.annotate(txt, (df['% of households over $200k'].iat[i], df['% of households less than $10k'].iat[i]))

plt.legend()
plt.show()

# %% [markdown]
# What conclusions do you draw from this data? In what ways could this be misleading? Is there a better visualization that you would use here? What would be your followup analysis?

# %%
merged_df.to_csv("congressional_district_with_parties.csv")

# %% [markdown]
# We hypothesize that the vacancy rate for all homes will be higher in republican districts than democrat districts. We think that this is the case because as seen above, the democrats represent the wealthiest districts and thus people in those districts would be more likely to have housing than not.

# %%
import numpy as np
import pandas as pd
from plotnine import *

# %% [markdown]
# We found our dataset from data.census.gov, which provided us with the total housing, as well as occupied and vacant housing amounts.

# %%
housing_data = pd.read_excel("Data/ACSDT1Y2022.B25002-2024-01-17T031427.xlsx", sheet_name="Data")
housing_data.head()
# Out:
#   Unnamed: 0 Congressional District 1 (118th Congress), Alabama  \
# 0      Label                                           Estimate
# 1     Total:                                             352830
# 2   Occupied                                             287884
# 3     Vacant                                              64946
#
#   Congressional District 2 (118th Congress), Alabama  \
# 0                                           Estimate
# 1                                             334262
# 2                                             285337
# 3                                              48925
#
#   Congressional District 3 (118th Congress), Alabama  \
# 0                                           Estimate
# 1                                             341469
# 2                                             294267
# 3                                              47202
#
#   Congressional District 4 (118th Congress), Alabama  \
# 0                                           Estimate
# 1                                             327413
# 2                                             280358
# 3                                              47055
#
#   Congressional District 5 (118th Congress), Alabama  \
# 0                                           Estimate
# 1                                             326553
# 2                                             298993
# 3                                              27560
#
#   Congressional District 6 (118th Congress), Alabama  \
# 0                                           Estimate
# 1                                             307351
# 2                                             281491
# 3                                              25860
#
#   Congressional District 7 (118th Congress), Alabama  \
# 0                                           Estimate
# 1                                             349704
# 2                                             288118
# 3                                              61586
#
#   Congressional District (at Large) (118th Congress), Alaska  \
# 0                                           Estimate
# 1                                             329160
# 2                                             274574
# 3                                              54586
#
#   Congressional District 1 (118th Congress), Arizona  ...  \
# 0                                           Estimate  ...
# 1                                             404498  ...
# 2                                             361781  ...
# 3                                              42717  ...
#
#   Congressional District 1 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             325976
# 2                                             300701
# 3                                              25275
#
#   Congressional District 2 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             340476
# 2                                             326875
# 3                                              13601
#
#   Congressional District 3 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             338312
# 2                                             307848
# 3                                              30464
#
#   Congressional District 4 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             334081
# 2                                             302427
# 3                                              31654
#
#   Congressional District 5 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             319980
# 2                                             308181
# 3                                              11799
#
#   Congressional District 6 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             338479
# 2                                             313119
# 3                                              25360
#
#   Congressional District 7 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             420681
# 2                                             320287
# 3                                             100394
#
#   Congressional District 8 (118th Congress), Wisconsin  \
# 0                                           Estimate
# 1                                             352370
# 2                                             311683
# 3                                              40687
#
#   Congressional District (at Large) (118th Congress), Wyoming  \
# 0                                           Estimate
# 1                                             277106
# 2                                             243321
# 3                                              33785
#
#   Resident Commissioner District (at Large) (118th Congress), Puerto Rico
# 0                                           Estimate
# 1                                            1598570
# 2                                            1289311
# 3                                             309259
#
# [4 rows x 438 columns]

# %%
result = []
for entry in housing_data.columns[1:]:
    entry = entry.split()
    district_index = entry.index('District')
    district_number = entry[district_index + 1]
    if district_number in "(at":
        district_number = 0
    
    state_name_index = entry.index('Congress),') + 1
    state_name = entry[state_name_index]
    if state_name in ["New", "West", "North", "South", "Rhode", "Puerto"]:
        state_name = entry[state_name_index] + " " + entry[state_name_index + 1]
    if "District" in state_name:
        state_name = entry[state_name_index] + " " + entry[state_name_index + 1] + " " + entry[state_name_index + 2]
    
    result.append([state_name, district_number])

clean_housing = pd.DataFrame(result)
clean_housing.columns = ["State", "district number"]

vacancy_rates = []
for entry in housing_data.columns[1:]:
    try:
        vacancy_rates.append(int(housing_data[entry][3]) / int(housing_data[entry][2]))
    except ValueError: 
        vacancy_rates.append(.039)
        
clean_housing["Vacancy Rate"] = vacancy_rates
clean_housing = clean_housing.drop(index=[87, 436])

# %%
clean_housing
# Out:
#          State district number  Vacancy Rate
# 0      Alabama               1      0.225598
# 1      Alabama               2      0.171464
# 2      Alabama               3      0.160405
# 3      Alabama               4      0.167839
# 4      Alabama               5      0.092176
# ..         ...             ...           ...
# 431  Wisconsin               5      0.038286
# 432  Wisconsin               6      0.080992
# 433  Wisconsin               7      0.313450
# 434  Wisconsin               8      0.130540
# 435    Wyoming               0      0.138850
#
# [435 rows x 3 columns]

# %%
joined_data[(joined_data["Total Households"] > 300000) & (joined_data["Vacancy Rate"]> .3)]
# Out:
#               State  district number  Vacancy Rate  Total Households  \
# 104         Florida               19      0.411667            365873
# 196        Michigan                1      0.381553            306685
# 289  North Carolina               11      0.301613            318745
# 424       Wisconsin                7      0.313450            313108
#
#      Less than $10k  $200k+  % of households over $200k  \
# 104           21299   39906                   10.907063
# 196           19036   12208                    3.980632
# 289           19450   14519                    4.555052
# 424           13243   16713                    5.337775
#
#      % of households less than $10k Party
# 104                        5.821419     R
# 196                        6.207020     R
# 289                        6.102057     R
# 424                        4.229531     R

# %%
clean_housing["State"] = clean_housing["State"].astype(str)
clean_housing["district number"] = clean_housing["district number"].astype(int)
merged_df["State"] = merged_df["State"].astype(str)
merged_df["district number"] = merged_df["district number"].astype(int)

joined_data = pd.merge(clean_housing, merged_df, on = ["State", "district number"])
joined_data
# Out:
#          State  district number  Vacancy Rate  Total Households  \
# 0      Alabama                1      0.225598            287768
# 1      Alabama                2      0.171464            267988
# 2      Alabama                3      0.160405            285773
# 3      Alabama                4      0.167839            265042
# 4      Alabama                5      0.092176            312227
# ..         ...              ...           ...               ...
# 422  Wisconsin                5      0.038286            310413
# 423  Wisconsin                6      0.080992            303251
# 424  Wisconsin                7      0.313450            313108
# 425  Wisconsin                8      0.130540            311259
# 426    Wyoming                0      0.138850            242763
#
#      Less than $10k  $200k+  % of households over $200k  \
# 0             22411   12033                    4.181493
# 1             22053   10659                    3.977417
# 2             26313    9731                    3.405150
# 3             19087   10066                    3.797889
# 4             18511   24457                    7.833083
# ..              ...     ...                         ...
# 422           11268   29305                    9.440648
# 423           12333   17590                    5.800476
# 424           13243   16713                    5.337775
# 425           13138   17638                    5.666663
# 426           14659   14179                    5.840676
#
#      % of households less than $10k Party
# 0                          7.787871     R
# 1                          8.229100     R
# 2                          9.207658     R
# 3                          7.201500     R
# 4                          5.928699     R
# ..                              ...   ...
# 422                        3.630003     R
# 423                        4.066928     R
# 424                        4.229531     R
# 425                        4.220922     R
# 426                        6.038400     R
#
# [427 rows x 9 columns]

# %%
from plotnine import *

# %%
(ggplot(joined_data, aes(x = "Party", y = "Vacancy Rate", fill = "Party"))
+ geom_boxplot()
+ labs(x = 'Party', y = 'Vacancy Rate') +
scale_fill_manual(values={'D': 'blue', 'R': 'red', 'L': 'yellow'})
 + theme_bw())
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(joined_data, aes(x='State', y='Vacancy Rate', fill='Party')) +
    geom_bar(stat='identity', position='dodge') +
    labs(x='Party', y='Vacancy Rate') +
    scale_fill_manual(values={'D': 'blue', 'R': 'red', 'L': 'yellow'}) +
    theme_bw() +
    theme(axis_text_x=element_text(angle=45, hjust=1))+
    theme(figure_size=(12, 6))
)
# Out:
# <Figure Size: (1200 x 600)>

# %%
(ggplot(joined_data,
aes(
  x = "Total Households",
  y = "Vacancy Rate",
  fill = "Party"
))
+ geom_point()
 + theme_bw()
  + theme(figure_size = (10, 4.5))
 + scale_size([1,20])
 + scale_fill_manual(values = {'D':'blue', 'R': 'red', "L": 'yellow'} )
+ theme(legend_title = element_blank()) + guides(size=False)
 + labs(x = 'Total Households', y = 'Vacancy Rate')
)
# Out:
# <Figure Size: (1000 x 450)>

# %%
(ggplot(joined_data, aes(x='Party', y='Vacancy Rate', fill='Party')) +
    geom_violin() +
    labs(x='Party', y='Vacancy Rate') +
    scale_fill_manual(values={'D': 'blue', 'R': 'red', 'L': 'yellow'}) +
    theme_bw()
)
# Out:
# C:\Users\jamla\anaconda33\Lib\site-packages\plotnine\stats\stat_density.py:164: PlotnineWarning: To compute the density of a group with only one value set the bandwidth manually. e.g `bw=0.1`
# C:\Users\jamla\anaconda33\Lib\site-packages\plotnine\stats\stat_density.py:169: PlotnineWarning: Groups with fewer than 2 data points have been removed.
# <Figure Size: (640 x 480)>

# %%
ca_joined = joined_data[joined_data["State"] == "California"]

# %%
(ggplot(ca_joined, aes(x='district number', y='Vacancy Rate', fill='Party')) +
    geom_bar(stat='identity', position='stack') +
    labs(x='Party', y='Vacancy Rate') +
    scale_fill_manual(values={'D': 'blue', 'R': 'red', 'L': 'yellow'}) +
    theme_bw()
)
# Out:
# <Figure Size: (640 x 480)>

# %%
(ggplot(ca_joined, aes(x = "Party", y = "Vacancy Rate", fill = "Party"))
+ geom_boxplot()
+ labs(x = 'Party', y = 'Vacancy Rate') +
scale_fill_manual(values={'D': 'blue', 'R': 'red', 'L': 'yellow'})
 + theme_bw())
# Out:
# <Figure Size: (640 x 480)>
